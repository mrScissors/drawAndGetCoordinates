# %%
import pygame, sys
from pygame.locals import *
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
coordinates = []

# %%
def main():
    pygame.init()
    coordinates.clear()
    WHITE = (255, 255, 255)
    BLACK = (0, 0, 0)

    mouse_position = (0, 0)
    drawing = False
    screen = pygame.display.set_mode((600, 800), 0, 32)
    screen.fill(WHITE)
    pygame.display.set_caption("ScratchBoard")

    last_pos = None

    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == MOUSEMOTION:
                if (drawing):
                    mouse_position = pygame.mouse.get_pos()
                    coordinates.append(mouse_position)
                    if last_pos is not None:
                        pygame.draw.line(screen, BLACK, last_pos, mouse_position, 1)
                    last_pos = mouse_position
            elif event.type == MOUSEBUTTONUP:
                mouse_position = (0, 0)
                drawing = False
            elif event.type == MOUSEBUTTONDOWN:
                drawing = True

        pygame.display.update()

if __name__ == "__main__":
    main()
# Out:
# (141, 338)
# (140, 334)
# (140, 327)
# (140, 321)
# (140, 311)
# (140, 302)
# (140, 293)
# (140, 281)
# (140, 269)
# (140, 256)
# (141, 242)
# (144, 229)
# (146, 217)
# (149, 205)
# (153, 192)
# (157, 181)
# (161, 169)
# (167, 158)
# (176, 138)
# (181, 130)
# (186, 121)
# (193, 115)
# (199, 109)
# (206, 104)
# (213, 99)
# (221, 95)
# (235, 90)
# (243, 89)
# (250, 89)
# (263, 89)
# (269, 89)
# (276, 90)
# (280, 91)
# (286, 94)
# (291, 98)
# (295, 101)
# (300, 107)
# (305, 113)
# (310, 120)
# (315, 130)
# (324, 149)
# (328, 160)
# (331, 171)
# (335, 184)
# (336, 198)
# (337, 213)
# (337, 229)
# (338, 244)
# (337, 271)
# (337, 286)
# (335, 299)
# (333, 312)
# (329, 324)
# (325, 333)
# (319, 345)
# (309, 363)
# (303, 370)
# (297, 378)
# (291, 385)
# (284, 390)
# (277, 396)
# (270, 400)
# (257, 406)
# (248, 408)
# (243, 410)
# (236, 412)
# (229, 413)
# (223, 414)
# (218, 415)
# (212, 415)
# (203, 415)
# (198, 414)
# (194, 413)
# (186, 409)
# (181, 407)
# (179, 404)
# (177, 402)
# (174, 398)
# (172, 394)
# (169, 388)
# (167, 382)
# (166, 377)
# (165, 370)
# (163, 363)
# (161, 346)
# (161, 338)
# (161, 330)
# (162, 323)
# (163, 315)
# (165, 308)
# (168, 300)
# (172, 293)
# (176, 287)
# (181, 279)
# (186, 272)
# (193, 266)
# (206, 254)
# (215, 250)
# (223, 247)
# (253, 241)
# (264, 240)
# (286, 240)
# (297, 240)
# (309, 240)
# (330, 245)
# (341, 249)
# (351, 255)
# (361, 261)
# (371, 268)
# (380, 275)
# (389, 284)
# (396, 293)
# (410, 313)
# (414, 324)
# (418, 335)
# (422, 358)
# (423, 370)
# (423, 382)
# (423, 406)
# (423, 417)
# (422, 428)
# (418, 448)
# (415, 457)
# (413, 465)
# (408, 479)
# (405, 486)
# (402, 492)
# (399, 497)
# (397, 501)
# (395, 503)
# (394, 504)
# (392, 506)
# (392, 507)
# (391, 506)
# (391, 503)
# (391, 499)
# (391, 493)
# (391, 485)
# (391, 476)
# (391, 465)
# (391, 455)
# (391, 443)
# (391, 431)
# (392, 418)
# (392, 403)
# (393, 390)
# (395, 375)
# (397, 350)
# (401, 327)
# (402, 315)
# (404, 305)
# (405, 296)
# (408, 286)
# (410, 278)
# (411, 271)
# (413, 264)
# (414, 257)
# (415, 252)
# (415, 246)
# (415, 242)
# (415, 237)
# (415, 236)
# (415, 233)
# (415, 231)
# (414, 230)
# (413, 229)
# (412, 228)
# (411, 228)
# (409, 228)
# (406, 228)
# (401, 228)
# (397, 229)
# (394, 232)
# (388, 237)
# (382, 241)
# (375, 247)
# (369, 253)
# (362, 260)
# (344, 275)
# (335, 284)
# (325, 294)
# (297, 324)
# (288, 334)
# (278, 346)
# (269, 356)
# (260, 366)
# (251, 376)
# (242, 386)
# (234, 395)
# (227, 404)
# (219, 412)
# (212, 421)
# (206, 429)
# (200, 436)
# (194, 443)
# (190, 451)
# (182, 461)
# (180, 465)
# (178, 466)
# (176, 469)
# (175, 470)
# (174, 470)
# (174, 469)
# (174, 467)
# (174, 464)
# (174, 459)
# (173, 454)
# (172, 447)
# (170, 438)
# (169, 430)
# (168, 422)
# (166, 413)
# (164, 403)
# (162, 392)
# (160, 381)
# (157, 369)
# (154, 356)
# (150, 331)
# (148, 318)
# (147, 305)
# (146, 293)
# (146, 270)
# (146, 261)
# (147, 253)
# (149, 246)
# (153, 238)
# (157, 232)
# (161, 228)
# (171, 221)
# (178, 218)
# (184, 217)
# (194, 216)
# (202, 216)
# (212, 216)
# (223, 216)
# (248, 220)
# (262, 224)
# (278, 230)
# (296, 238)
# (316, 248)
# (335, 258)
# (353, 268)
# (372, 280)
# (390, 289)
# (407, 302)
# (421, 312)
# (436, 324)
# (448, 335)
# (461, 348)
# (471, 358)
# (480, 368)
# (487, 377)
# (495, 386)
# (503, 393)
# (510, 401)
# (516, 408)
# (522, 414)
# (527, 420)
# (529, 425)
# (532, 429)
# (534, 431)
# (534, 433)
# (535, 434)
# (535, 435)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Sudhindra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
coordinates
# Out:
# [(141, 338),
#  (140, 334),
#  (140, 327),
#  (140, 321),
#  (140, 311),
#  (140, 302),
#  (140, 293),
#  (140, 281),
#  (140, 269),
#  (140, 256),
#  (141, 242),
#  (144, 229),
#  (146, 217),
#  (149, 205),
#  (153, 192),
#  (157, 181),
#  (161, 169),
#  (167, 158),
#  (176, 138),
#  (181, 130),
#  (186, 121),
#  (193, 115),
#  (199, 109),
#  (206, 104),
#  (213, 99),
#  (221, 95),
#  (235, 90),
#  (243, 89),
#  (250, 89),
#  (263, 89),
#  (269, 89),
#  (276, 90),
#  (280, 91),
#  (286, 94),
#  (291, 98),
#  (295, 101),
#  (300, 107),
#  (305, 113),
#  (310, 120),
#  (315, 130),
#  (324, 149),
#  (328, 160),
#  (331, 171),
#  (335, 184),
#  (336, 198),
#  (337, 213),
#  (337, 229),
#  (338, 244),
#  (337, 271),
#  (337, 286),
#  (335, 299),
#  (333, 312),
#  (329, 324),
#  (325, 333),
#  (319, 345),
#  (309, 363),
#  (303, 370),
#  (297, 378),
#  (291, 385),
#  (284, 390),
#  (277, 396),
#  (270, 400),
#  (257, 406),
#  (248, 408),
#  (243, 410),
#  (236, 412),
#  (229, 413),
#  (223, 414),
#  (218, 415),
#  (212, 415),
#  (203, 415),
#  (198, 414),
#  (194, 413),
#  (186, 409),
#  (181, 407),
#  (179, 404),
#  (177, 402),
#  (174, 398),
#  (172, 394),
#  (169, 388),
